# %% [markdown]
# Player5 avec des embeddings qui capturent mieux les relations, des descriptiosn sémantiques sont présentes ou des graphes
# -

# %% [markdown]
# 1 : Items
# -
# Utilisation de tags descriptifs

# %%
item_to_id = {
    "choiceband": 0,
    "choicescarf": 1,
    "choicespecs": 2,
    "expertbelt": 3,
    "focussash": 4,
    "leftovers": 5,
    "lifeorb": 6,
    "lumberry": 7,
    "powerherb": 8,
    "salacberry": 9,
    "sitrusberry": 10,
    "blacksludge": 11,
    "thickclub": 12,       # os de Ossatueur (Marowak)
    "lightball": 13,       # objet de Pikachu
    "flameplate": 14, 
    "fistplate": 15,
     "earthplate": 16, 
     "stoneplate": 17, 
     "zapplate": 18,
    "meadowplate": 19, 
    "icicleplate": 20, 
    "toxicplate": 21, 
    "mindplate": 22, 
    "insectplate": 23,
    "spookyplate": 24, 
    "dracoplate": 25, 
    "dreadplate": 26, 
    "ironplate": 27, 
    "skyplate": 28,
    "splashplate": 29
}


tag_to_id = {
    "boost": 0,
    "attack": 1,
    "speed": 2,
    "spa": 3,
    "lock": 4,
    "healing": 5,
    "passive": 6,
    "status-cure": 7,
    "hp-threshold": 8,
    "single-use": 9,
    "survive": 10,
    "setup": 11,
    "charge-cancel": 12,
    "recoil": 13,
    "signature": 14,
    "super-effective": 15,
    "poison-type": 16,
    "atk-double": 17,
    "spa-double": 18,
    "marowak": 19,
    "pikachu": 20,
    "plate": 21,
    "normal": 22,
    "fire": 23,
    "water": 24,
    "electric": 25,
    "grass": 26,
    "ice": 27,
    "fighting": 28,
    "ground": 30,
    "flying": 31,
    "psychic": 32,
    "bug": 33,
    "rock": 34,
    "ghost": 35,
    "dragon": 36,
    "dark": 37,
    "steel": 38,
    "low_boost": 39
}


item_to_tags = {
    "choiceband": ["boost", "attack", "lock"],
    "choicescarf": ["boost", "speed", "lock"],
    "choicespecs": ["boost", "spa", "lock"],
    "lifeorb": ["boost", "recoil"],
    "expertbelt": ["boost", "super-effective"],
    "focussash": ["survive", "single-use"],
    "leftovers": ["healing", "passive"],
    "blacksludge": ["healing", "passive", "poison"],
    "sitrusberry": ["healing", "hp-threshold", "single-use"],
    "salacberry": ["boost", "speed", "hp-threshold", "single-use"],
    "lumberry": ["status-cure", "single-use"],
    "powerherb": ["setup", "charge-cancel", "single-use"],
    "thickclub": ["signature", "atk-double", "marowak"],
    "lightball": ["signature", "spa-double", "pikachu"],
    "flameplate": ["low_boost", "plate", "fire"],
    "fistplate": ["low_boost", "plate", "fighting"],
    "earthplate": ["low_boost", "plate", "ground"],
    "stoneplate": ["low_boost", "plate", "rock"],
    "zapplate": ["low_boost", "plate", "electric"],
    "meadowplate": ["low_boost", "plate", "grass"],
    "icicleplate": ["low_boost", "plate", "ice"],
    "toxicplate": ["low_boost", "plate", "poison"],
    "mindplate": ["low_boost", "plate", "psychic"],
    "insectplate": ["low_boost", "plate", "bug"],
    "spookyplate": ["low_boost", "plate", "ghost"],
    "dracoplate": ["low_boost", "plate", "dragon"],
    "dreadplate": ["low_boost", "plate", "dark"],
    "ironplate": ["low_boost", "plate", "steel"],
    "skyplate": ["low_boost", "plate", "flying"],
    "splashplate": ["low_boost", "plate", "water"]
}
